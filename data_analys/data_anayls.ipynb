# %%
import os

# 현재 위치에서 두 단계 위(루트)로 이동
os.chdir('/Users/chanwoo/Desktop/python_multithread/src')
print(f"현재 작업 디렉토리: {os.getcwd()}")
# Out:
# 현재 작업 디렉토리: /Users/chanwoo/Desktop/python_multithread/src

# %%
import pandas as pd
import util.project_resource_path
# 1. 데이터 불러오기
df = pd.read_csv(util.project_resource_path.project_path+"/csv_file/student_performance.csv")

# %%
# 2. 전체적인 구조 확인 (자바의 클래스 구조 확인과 비슷함)
print("### 1. 데이터 기본 정보 ###")
print(df.info()) 
print("-" * 30)

# 3. 상위 5개 데이터 미리보기
print("### 2. 데이터 샘플 (Top 5) ###")
print(df.head())
print("-" * 30)

# 4. 수치형 데이터의 통계 요약 (평균, 최소, 최대, 4분위수 등)
print("### 3. 수치 데이터 통계 요약 ###")
print(df.describe())
print("-" * 30)

# 5. 각 컬럼별 고유값(Unique) 개수 확인
print("### 4. 컬럼별 고유값 개수 ###")
print(df.nunique())
# Out:
# ### 1. 데이터 기본 정보 ###
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            5000 non-null   int64
#  1   age                   5000 non-null   int64
#  2   gender                5000 non-null   str
#  3   academic_level        5000 non-null   str
#  4   study_hours           5000 non-null   float64
#  5   self_study_hours      5000 non-null   float64
#  6   online_classes_hours  5000 non-null   float64
#  7   social_media_hours    5000 non-null   float64
#  8   gaming_hours          5000 non-null   float64
#  9   sleep_hours           5000 non-null   float64
#  10  screen_time_hours     5000 non-null   float64
#  11  exercise_minutes      5000 non-null   int64
#  12  caffeine_intake_mg    5000 non-null   int64
#  13  part_time_job         5000 non-null   int64
# ...

# %%
# 'academic_level' 열에 어떤 학년들이 있는지 확인
print(df['academic_level'].unique())

# 결과 예시: ['Freshman' 'Sophomore' 'Junior' 'Senior']
# Out:
# <StringArray>
# ['High School', 'Undergraduate', 'Postgraduate']
# Length: 3, dtype: str
